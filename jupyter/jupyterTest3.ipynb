# %%
import pandas as pd
data = pd.read_pickle("../datasets/electric/201802_nopay_data.pkl")
data.head()
# Out:
#       supply_unit             B    user_id chaobiaoduan station regions  \
# 30825     沪东营销分中心  6.419119e+09  114033813       A44231    市区控江     杨浦区
# 38757     沪东营销分中心  6.419120e+09  111059664       A44621    市区控江     杨浦区
# 57177     沪东营销分中心  6.417408e+09   60261584       A645B1    市区控江     杨浦区
# 57178     沪东营销分中心  6.417408e+09   60261640       A645B1    市区控江     杨浦区
# 80415     沪东营销分中心  6.411056e+09   60223635       AL28J2    市区九龙     虹口区
#
#               address  fee  flat_power  valley_power  bill_post_time  \
# 30825   国权路95弄14号901室  0.0         0.0           0.0      20180209.0
# 38757  国顺路117弄35号502室  0.0         0.0           0.0      20180209.0
# 57177    翔殷路995号1005室  0.0         0.0           0.0      20180207.0
# 57178    翔殷路995号2201室  0.0         0.0           0.0      20180207.0
# 80415  欧阳路555弄8号1706室  0.0         0.0           0.0      20180204.0
#
#       payment_time channel    location      Lng     Lat payment_time_2  \
# ...

# %%
data1 = pd.read_pickle("../datasets/electric/201803_nopay_data.pkl")
data1.head()
# Out:
#        supply_unit             B    user_id chaobiaoduan station regions  \
# 3845       沪东营销分中心  6.427305e+09   61234549       A63201    市区控江     杨浦区
# 109488     沪东营销分中心  6.424162e+09  111009431       A531A2    市区控江     杨浦区
# 159971     沪东营销分中心  6.429861e+09  114130080       A538F1    市区控江     杨浦区
# 160125     沪东营销分中心  6.429877e+09  111093618       A54121    市区控江     杨浦区
# 161692     沪东营销分中心  6.429877e+09   61321781       A54121    市区控江     杨浦区
#
#                  address  fee  flat_power  valley_power  bill_post_time  \
# 3845    延吉中路365弄13号1301室  0.0         0.0           0.0      20180306.0
# 109488        黎平路95弄34号甲  0.0         0.0           0.0      20180305.0
# 159971      杨树浦路1629弄33号  0.0         0.0           0.0      20180309.0
# 160125      杨树浦路1851弄49号  0.0         0.0           0.0      20180309.0
# 161692    杨树浦路1825弄35号底楼  0.0         0.0           0.0      20180309.0
#
#        payment_time channel      location      Lng     Lat payment_time_2  \
# ...

# %%
temp = data[['user_id', 'regions', 'address', 'fee', 'flat_power', 'valley_power', 'Lng', 'Lat']]
temp.head()
# Out:
#          user_id regions         address  fee  flat_power  valley_power  \
# 30825  114033813     杨浦区   国权路95弄14号901室  0.0         0.0           0.0
# 38757  111059664     杨浦区  国顺路117弄35号502室  0.0         0.0           0.0
# 57177   60261584     杨浦区    翔殷路995号1005室  0.0         0.0           0.0
# 57178   60261640     杨浦区    翔殷路995号2201室  0.0         0.0           0.0
# 80415   60223635     虹口区  欧阳路555弄8号1706室  0.0         0.0           0.0
#
#            Lng     Lat
# 30825  121.523  31.292
# 38757  121.522  31.295
# 57177  121.528  31.306
# 57178  121.528  31.306
# 80415  121.494  31.280

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 373 entries, 30825 to 7579228
# Data columns (total 8 columns):
# user_id         373 non-null int64
# regions         373 non-null object
# address         373 non-null object
# fee             373 non-null float64
# flat_power      363 non-null float64
# valley_power    367 non-null float64
# Lng             373 non-null float64
# Lat             373 non-null float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 26.2+ KB

# %%
temp1 = data1[['user_id', 'fee', 'flat_power', 'valley_power']]
temp1.rename(columns = {"fee": "fee201803", "flat_power":"flat_power201803", "valley_power":"valley_power201803"},  inplace=True)

temp2 = temp.merge(temp1, on='user_id', how='outer')
temp2
# Out:
#         user_id regions                 address  fee  flat_power  \
# 0     114033813     杨浦区           国权路95弄14号901室  0.0         0.0
# 1     111059664     杨浦区          国顺路117弄35号502室  0.0         0.0
# 2      60261584     杨浦区            翔殷路995号1005室  0.0         0.0
# 3      60261640     杨浦区            翔殷路995号2201室  0.0         0.0
# 4      60223635     虹口区          欧阳路555弄8号1706室  0.0         0.0
# 5      61724047     杨浦区        中山北二路99弄57号1501室  0.0         0.0
# 6     111080288     杨浦区           延吉东路82弄1号201室  0.0         0.0
# 7     111184189     杨浦区              辽源新村233号甲上  0.0         0.0
# 8     114022475     虹口区           临平路333号6座902室  0.0         0.0
# 9     111400752     黄浦区             汉口路457号415室  0.0         0.0
# 10    114070340     杨浦区           江浦路666弄4号601室  0.0         0.0
# 11    114156060     杨浦区               许昌路698弄5号  0.0         0.0
# 12     62844877     杨浦区               许昌路698弄5号  0.0         0.0
# ...

# %%
temp3 = temp.merge(temp1, on='user_id', how='inner')
temp3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 30
# Data columns (total 11 columns):
# user_id               31 non-null int64
# regions               31 non-null object
# address               31 non-null object
# fee                   31 non-null float64
# flat_power            29 non-null float64
# valley_power          29 non-null float64
# Lng                   31 non-null float64
# Lat                   31 non-null float64
# fee201803             31 non-null float64
# flat_power201803      29 non-null float64
# valley_power201803    29 non-null float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 2.9+ KB

# %%
temp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 246 entries, 3845 to 7620751
# Data columns (total 4 columns):
# user_id               246 non-null int64
# fee201803             246 non-null float64
# flat_power201803      239 non-null float64
# valley_power201803    244 non-null float64
# dtypes: float64(3), int64(1)
# memory usage: 9.6 KB

# %%
temp2.describe()
# Out:
#             user_id         fee    flat_power  valley_power         Lng  \
# count  5.880000e+02  373.000000    363.000000    367.000000  373.000000
# mean   5.186389e+08   -5.791635    112.000000     71.623978  120.440086
# std    1.128377e+09   58.457121    912.715165    625.619178   10.950316
# min    1.789500e+04 -785.540000    -38.000000    -85.000000   -1.000000
# 25%    6.137408e+07    0.000000      0.000000      0.000000  121.355000
# 50%    1.220458e+08    0.000000      0.000000      0.000000  121.438000
# 75%    2.312213e+08    0.000000      0.000000      0.000000  121.496000
# max    6.808027e+09   11.200000  13040.000000  10592.000000  121.833000
#
#               Lat   fee201803  flat_power201803  valley_power201803
# count  373.000000  246.000000        239.000000          244.000000
# mean    30.980922   -2.983659         10.753138            3.799180
# std      2.886960   25.736098        122.602871           81.817803
# ...

# %%
temp2['fee'].min()
# Out:
# -785.54

# %%
notna_data_a = pd.read_pickle("../datasets/electric/201802_notna_date_data.pkl")
notna_data_b = pd.read_pickle("../datasets/electric/201803_notna_date_data.pkl")
df_a = notna_data_a[['user_id', 'regions', 'address', 'fee', 'flat_power', 'valley_power', 'Lng', 'Lat']]
df_b = notna_data_b[['user_id', 'fee', 'flat_power', 'valley_power']]
df_b.rename(columns = {"fee": "fee201803", "flat_power":"flat_power201803", "valley_power":"valley_power201803"},  inplace=True)

df_c = df_a.merge(df_b, on='user_id', how='outer')
df_c.head()
# Out:
# /Users/Shared/Anaconda/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#       user_id regions               address    fee  flat_power  valley_power  \
# 0  1226239768     虹口区  上海市虹口区物华路118弄4号2202室   60.1        86.0          23.0
# 1  1226238000     虹口区  上海市虹口区物华路118弄3号2004室  536.0       701.0         337.0
# 2  1226237443     虹口区   上海市虹口区物华路118弄3号604室  126.1       179.0          51.0
# 3  1226237430     虹口区   上海市虹口区物华路118弄3号603室  131.5       128.0         171.0
# 4  1226625666     虹口区  上海市虹口区物华路118弄5号2101室   25.8       561.0         238.0
#
#      Lng     Lat  fee201803  flat_power201803  valley_power201803
# 0  121.5  31.265       60.4              85.0                26.0
# ...

# %%
df_d = df_a.merge(df_b, on='user_id', how='inner')
df_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7626523 entries, 0 to 7626522
# Data columns (total 11 columns):
# user_id               int64
# regions               object
# address               object
# fee                   float64
# flat_power            float64
# valley_power          float64
# Lng                   float64
# Lat                   float64
# fee201803             float64
# flat_power201803      float64
# valley_power201803    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 698.2+ MB

# %%
df_a.info()
df_b.info()
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7626738 entries, 0 to 7627110
# Data columns (total 8 columns):
# user_id         int64
# regions         object
# address         object
# fee             float64
# flat_power      float64
# valley_power    float64
# Lng             float64
# Lat             float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 523.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7626865 entries, 0 to 7627110
# Data columns (total 4 columns):
# user_id               int64
# fee201803             float64
# flat_power201803      float64
# valley_power201803    float64
# dtypes: float64(3), int64(1)
# memory usage: 290.9 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7627080 entries, 0 to 7627079
# Data columns (total 11 columns):
# user_id               int64
# regions               object
# address               object
# fee                   float64
# flat_power            float64
# valley_power          float64
# ...

# %%
notna_data_04 = pd.read_pickle("../datasets/electric/201804_notna_date_data.pkl")
df_04 = notna_data_04[['user_id', 'fee', 'flat_power', 'valley_power']]
df_04.rename(columns = {"fee": "fee201804", "flat_power":"flat_power201804", "valley_power":"valley_power201804"},  inplace=True)
df_e = df_d.merge(df_04, on='user_id', how='inner')
df_e.info()
# Out:
# /Users/Shared/Anaconda/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7626321 entries, 0 to 7626320
# Data columns (total 14 columns):
# user_id               int64
# regions               object
# address               object
# fee                   float64
# flat_power            float64
# valley_power          float64
# Lng                   float64
# Lat                   float64
# fee201803             float64
# flat_power201803      float64
# valley_power201803    float64
# fee201804             float64
# flat_power201804      float64
# valley_power201804    float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 872.8+ MB

# %%
df_04.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7626884 entries, 0 to 7627110
# Data columns (total 4 columns):
# user_id               int64
# fee201804             float64
# flat_power201804      float64
# valley_power201804    float64
# dtypes: float64(3), int64(1)
# memory usage: 290.9 MB

# %%
data1 = pd.read_pickle("../datasets/electric/201804_data.pkl")
data1.head()
# Out:
#   supply_unit             B   user_id chaobiaoduan station regions  \
# 0     沪东营销分中心  6.440183e+09  60140344       A43413    市区控江     杨浦区
# 1     沪东营销分中心  6.440183e+09  60140357       A43414    市区控江     杨浦区
# 2     沪东营销分中心  6.440183e+09  60140363       A43414    市区控江     杨浦区
# 3     沪东营销分中心  6.440183e+09  60140200       A43414    市区控江     杨浦区
# 4     沪东营销分中心  6.440183e+09  60140204       A43414    市区控江     杨浦区
#
#          address    fee  flat_power  valley_power  bill_post_time  \
# 0  国康路46弄3号2201室   87.9       118.0          49.0      20180408.0
# 1  国康路46弄1号1303室  129.1       172.0          75.0      20180408.0
# 2  国康路46弄1号1503室  377.4       392.0         377.0      20180408.0
# 3   国康路46弄1号303室  146.1       195.0          84.0      20180408.0
# 4   国康路46弄1号501室  125.2       176.0          54.0      20180408.0
#
#           payment_time channel   location     Lng     Lat      payment_time_2  \
# 0  2018-04-23 17:02:29    人民银行  上海市国康路46弄  121.51  31.292 2018-04-23 17:02:29
# ...
